# %%
import cv2
import numpy as np
import random
import threading
import json
import time
import os
import sqlite3
import logging
import configparser


# Initialize the configuration parser
config = configparser.ConfigParser()
config.read('config.ini')

# Read configuration values
batch_duration = int(config['General']['batch_duration'])
log_file = config['General']['log_file']
log_level = config['General']['log_level']

# Create the "logs" folder if it doesn't exist
os.makedirs("logs", exist_ok=True)
# Configure logging
logging.basicConfig(filename=log_file, level=logging.getLevelName(log_level), format='%(asctime)s - %(levelname)s - %(message)s')



# Function to initialize the database connection pool
def init_db_pool():
    return sqlite3.connect("video_analytics.db", check_same_thread=False)

# Create a database connection pool
db_connection_pool = init_db_pool()

# Database setup
def setup_database():
    with db_connection_pool:
        cursor = db_connection_pool.cursor()

        # Create a table to store batch information
        cursor.execute('''CREATE TABLE IF NOT EXISTS batches
                        (batch_id INTEGER PRIMARY KEY AUTOINCREMENT,
                        camera_id TEXT,  -- Add a column for camera ID or name
                        starting_frame_id INTEGER,
                        ending_frame_id INTEGER,
                        timestamp INTEGER)''')

        # Create a table to store frame counts
        cursor.execute('''CREATE TABLE IF NOT EXISTS camera_frame_count
                        (camera_id TEXT PRIMARY KEY,
                        frame_count INTEGER)''')



# Function to log batch information to the database
def log_batch_info(camera_id, starting_frame_id, ending_frame_id, timestamp):
   with db_connection_pool:
        cursor = db_connection_pool.cursor()
        cursor.execute("INSERT INTO batches (camera_id,starting_frame_id, ending_frame_id, timestamp) VALUES (?, ?, ?, ?)",
                       (camera_id, starting_frame_id, ending_frame_id, timestamp))

# Function to retrieve frame count for a camera from the database
def get_frame_count(camera_id):
    with db_connection_pool:
        cursor = db_connection_pool.cursor()
        cursor.execute("SELECT frame_count FROM camera_frame_count WHERE camera_id = ?", (camera_id,))
        row = cursor.fetchone()
        if row:
            print(row[0])
            return row[0]
        else:
            return 0


# Function to update frame count for a camera in the database
def update_frame_count(camera_id, frame_count):
    with db_connection_pool:
        cursor = db_connection_pool.cursor()
        try:
            cursor.execute("INSERT OR REPLACE INTO camera_frame_count (camera_id, frame_count) VALUES (?, ?)",
                        (camera_id, frame_count))
        except Exception as e:
            logging.error(f'Exception occures: {str(e)}')


def create_camera_feeds(n):
    camera_feeds = []

    for i in range(n):
        # Initialize a VideoCapture object for the camera
        cap = cv2.VideoCapture(i)  # Use camera with index 'i'
        
        # Check if the camera was opened successfully
        if not cap.isOpened():
            print(f"Error: Could not open camera {i}.")
            continue
        fps = cap.get(cv2.CAP_PROP_FPS)

        # Check if the fps value is valid (some cameras may not provide it)
        if fps > 0:
            print(f"Frames per Second (FPS): {fps}")
        else:
            print("FPS information not available for this camera feed. setting fps to 25")
            fps = 25

        # Generate some random geolocation information (latitude and longitude)
        latitude = round(random.uniform(-90, 90), 6)
        longitude = round(random.uniform(-180, 180), 6)

        # Create camera metadata
        camera_metadata = {
            'camera_name': f'Camera_{i}',
            'geolocation': f'({latitude}, {longitude})',
            'fps':fps,
            'cap': cap,  # Store the VideoCapture object
        }

        camera_feeds.append(camera_metadata)

    return camera_feeds

def process_and_save_frames(metadata):
    camera_id = metadata['camera_name']
    frame_id = get_frame_count(camera_id)  # Retrieve frame count from the database

    fps = metadata['fps']

    # Create a directory for each camera if it doesn't exist
    camera_folder = os.path.join("images", camera_id)
    os.makedirs(camera_folder, exist_ok=True)

    # Variables for batch processing
    start_time = int(time.time())
    batch_start_frame = 0
    frame_count = 0 

    while True:
        # Capture a frame from the camera feed
        ret, frame = metadata['cap'].read()
        if not ret:
            break

        frame_id += 1
        

        try:
            # Process and create a JSON object for one frame per second
            if frame_id % fps == 0:
                timestamp = int(time.time())  # Unix timestamp
                frame_info = {
                    "camera_id": camera_id,
                    "frame_id": frame_id,
                    "geo_location": metadata["geolocation"],
                    "timestamp": timestamp,
                }

                # Write the frame as a jpg image file
                image_path = os.path.join(camera_folder, f"frame_{frame_id}.jpg")
                cv2.imwrite(image_path, frame)
                frame_info["image_path"] = image_path


                # Convert the frame information to JSON
                frame_json = json.dumps(frame_info)

                # Log JSON data with INFO level
                logging.info(frame_json)
                
                #print JSON 
                print(frame_json)

            # Check if the batch duration has been reached
            if int(time.time()) - start_time >= batch_duration:
                batch_start_frame = (frame_id - frame_count)
                log_batch_info(camera_id, batch_start_frame, frame_id, start_time)
                print(f'start frame id = {batch_start_frame}------ending frame id = {frame_id}-----timestamp{timestamp}-----start_time{start_time}')
                batch_start_frame = frame_id
                start_time = int(time.time())
                frame_count = 0
        except Exception as e:
            #Log exceptions with ERROR level
            logging.error(f'Exception occures: {str(e)}')

        update_frame_count(camera_id, frame_id)  # Update frame count in the database
        

# Create the "images" folder if it doesn't exist
os.makedirs("images", exist_ok=True)

#set up the database
setup_database()

n_cameras = 2  # Number of camera feeds to create
camera_feeds = create_camera_feeds(n_cameras)

# Create and start a thread for each camera feed
threads = []
for metadata in camera_feeds:
    thread = threading.Thread(target=process_and_save_frames, args=(metadata,))
    threads.append(thread)
    thread.start()

# Wait for all threads to finish (press 'q' to exit)
for thread in threads:
    thread.join()

# Release the VideoCapture objects when done
for metadata in camera_feeds:
    metadata["cap"].release()
# Out:
# Frames per Second (FPS): 30.0
# Frames per Second (FPS): 30.0
# cannot start a transaction within a transaction
# cannot start a transaction within a transaction
# Exception in thread Thread-6 (process_and_save_frames):
# Traceback (most recent call last):
#   File "c:\Users\melbi\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\melbi\AppData\Local\Programs\Python\Python310\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\melbi\AppData\Local\Temp\ipykernel_82440\1844121108.py", line 185, in process_and_save_frames
#   File "C:\Users\melbi\AppData\Local\Temp\ipykernel_82440\1844121108.py", line 78, in update_frame_count
# sqlite3.OperationalError: cannot commit - no transaction is active
# {"camera_id": "Camera_1", "frame_id": 30, "geo_location": "(-43.573482, 178.356441)", "timestamp": 1695718209, "image_path": "images\\Camera_1\\frame_30.jpg"}
# {"camera_id": "Camera_0", "frame_id": 30, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718210, "image_path": "images\\Camera_0\\frame_30.jpg"}
# {"camera_id": "Camera_0", "frame_id": 60, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718211, "image_path": "images\\Camera_0\\frame_60.jpg"}
# {"camera_id": "Camera_0", "frame_id": 90, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718212, "image_path": "images\\Camera_0\\frame_90.jpg"}
# {"camera_id": "Camera_0", "frame_id": 120, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718213, "image_path": "images\\Camera_0\\frame_120.jpg"}
# {"camera_id": "Camera_0", "frame_id": 150, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718214, "image_path": "images\\Camera_0\\frame_150.jpg"}
# {"camera_id": "Camera_0", "frame_id": 180, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718215, "image_path": "images\\Camera_0\\frame_180.jpg"}
# {"camera_id": "Camera_0", "frame_id": 210, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718216, "image_path": "images\\Camera_0\\frame_210.jpg"}
# {"camera_id": "Camera_0", "frame_id": 240, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718217, "image_path": "images\\Camera_0\\frame_240.jpg"}
# {"camera_id": "Camera_0", "frame_id": 270, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718218, "image_path": "images\\Camera_0\\frame_270.jpg"}
# {"camera_id": "Camera_0", "frame_id": 300, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718219, "image_path": "images\\Camera_0\\frame_300.jpg"}
# {"camera_id": "Camera_0", "frame_id": 330, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718220, "image_path": "images\\Camera_0\\frame_330.jpg"}
# {"camera_id": "Camera_0", "frame_id": 360, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718221, "image_path": "images\\Camera_0\\frame_360.jpg"}
# {"camera_id": "Camera_0", "frame_id": 390, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718222, "image_path": "images\\Camera_0\\frame_390.jpg"}
# {"camera_id": "Camera_0", "frame_id": 420, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718223, "image_path": "images\\Camera_0\\frame_420.jpg"}
# {"camera_id": "Camera_0", "frame_id": 450, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718224, "image_path": "images\\Camera_0\\frame_450.jpg"}
# {"camera_id": "Camera_0", "frame_id": 480, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718225, "image_path": "images\\Camera_0\\frame_480.jpg"}
# {"camera_id": "Camera_0", "frame_id": 510, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718226, "image_path": "images\\Camera_0\\frame_510.jpg"}
# {"camera_id": "Camera_0", "frame_id": 540, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718228, "image_path": "images\\Camera_0\\frame_540.jpg"}
# {"camera_id": "Camera_0", "frame_id": 570, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718229, "image_path": "images\\Camera_0\\frame_570.jpg"}
# {"camera_id": "Camera_0", "frame_id": 600, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718230, "image_path": "images\\Camera_0\\frame_600.jpg"}
# {"camera_id": "Camera_0", "frame_id": 630, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718232, "image_path": "images\\Camera_0\\frame_630.jpg"}
# {"camera_id": "Camera_0", "frame_id": 660, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718233, "image_path": "images\\Camera_0\\frame_660.jpg"}
# {"camera_id": "Camera_0", "frame_id": 690, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718234, "image_path": "images\\Camera_0\\frame_690.jpg"}
# {"camera_id": "Camera_0", "frame_id": 720, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718235, "image_path": "images\\Camera_0\\frame_720.jpg"}
# {"camera_id": "Camera_0", "frame_id": 750, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718236, "image_path": "images\\Camera_0\\frame_750.jpg"}
# {"camera_id": "Camera_0", "frame_id": 780, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718237, "image_path": "images\\Camera_0\\frame_780.jpg"}
# {"camera_id": "Camera_0", "frame_id": 810, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718238, "image_path": "images\\Camera_0\\frame_810.jpg"}
# {"camera_id": "Camera_0", "frame_id": 840, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718239, "image_path": "images\\Camera_0\\frame_840.jpg"}
# {"camera_id": "Camera_0", "frame_id": 870, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718240, "image_path": "images\\Camera_0\\frame_870.jpg"}
# {"camera_id": "Camera_0", "frame_id": 900, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718241, "image_path": "images\\Camera_0\\frame_900.jpg"}
# {"camera_id": "Camera_0", "frame_id": 930, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718242, "image_path": "images\\Camera_0\\frame_930.jpg"}
# {"camera_id": "Camera_0", "frame_id": 960, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718243, "image_path": "images\\Camera_0\\frame_960.jpg"}
# {"camera_id": "Camera_0", "frame_id": 990, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718244, "image_path": "images\\Camera_0\\frame_990.jpg"}
# {"camera_id": "Camera_0", "frame_id": 1020, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718245, "image_path": "images\\Camera_0\\frame_1020.jpg"}
# {"camera_id": "Camera_0", "frame_id": 1050, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718246, "image_path": "images\\Camera_0\\frame_1050.jpg"}
# {"camera_id": "Camera_0", "frame_id": 1080, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718247, "image_path": "images\\Camera_0\\frame_1080.jpg"}
# {"camera_id": "Camera_0", "frame_id": 1110, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695718248, "image_path": "images\\Camera_0\\frame_1110.jpg"}
# {"camera_id": "Camera_0", "frame_id": 1140, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695
"geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719376, "image_path": "images\\Camera_0\\frame_34800.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34830, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719377, "image_path": "images\\Camera_0\\frame_34830.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34860, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719378, "image_path": "images\\Camera_0\\frame_34860.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34890, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719379, "image_path": "images\\Camera_0\\frame_34890.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34920, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719380, "image_path": "images\\Camera_0\\frame_34920.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34950, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719381, "image_path": "images\\Camera_0\\frame_34950.jpg"}
# {"camera_id": "Camera_0", "frame_id": 34980, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719382, "image_path": "images\\Camera_0\\frame_34980.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35010, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719383, "image_path": "images\\Camera_0\\frame_35010.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35040, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719384, "image_path": "images\\Camera_0\\frame_35040.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35070, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719385, "image_path": "images\\Camera_0\\frame_35070.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35100, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719386, "image_path": "images\\Camera_0\\frame_35100.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35130, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719387, "image_path": "images\\Camera_0\\frame_35130.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35160, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719388, "image_path": "images\\Camera_0\\frame_35160.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35190, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719389, "image_path": "images\\Camera_0\\frame_35190.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35220, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719390, "image_path": "images\\Camera_0\\frame_35220.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35250, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719391, "image_path": "images\\Camera_0\\frame_35250.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35280, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719392, "image_path": "images\\Camera_0\\frame_35280.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35310, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719393, "image_path": "images\\Camera_0\\frame_35310.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35340, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719394, "image_path": "images\\Camera_0\\frame_35340.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35370, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719395, "image_path": "images\\Camera_0\\frame_35370.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35400, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719396, "image_path": "images\\Camera_0\\frame_35400.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35430, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719397, "image_path": "images\\Camera_0\\frame_35430.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35460, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719398, "image_path": "images\\Camera_0\\frame_35460.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35490, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719399, "image_path": "images\\Camera_0\\frame_35490.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35520, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719400, "image_path": "images\\Camera_0\\frame_35520.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35550, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719401, "image_path": "images\\Camera_0\\frame_35550.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35580, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719402, "image_path": "images\\Camera_0\\frame_35580.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35610, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719403, "image_path": "images\\Camera_0\\frame_35610.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35640, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719404, "image_path": "images\\Camera_0\\frame_35640.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35670, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719405, "image_path": "images\\Camera_0\\frame_35670.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35700, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719406, "image_path": "images\\Camera_0\\frame_35700.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35730, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719407, "image_path": "images\\Camera_0\\frame_35730.jpg"}
# start frame id = 35739------ending frame id = 35739-----timestamp1695719407-----start_time1695719348
# {"camera_id": "Camera_0", "frame_id": 35760, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719408, "image_path": "images\\Camera_0\\frame_35760.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35790, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719409, "image_path": "images\\Camera_0\\frame_35790.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35820, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719410, "image_path": "images\\Camera_0\\frame_35820.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35850, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719411, "image_path": "images\\Camera_0\\frame_35850.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35880, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719412, "image_path": "images\\Camera_0\\frame_35880.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35910, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719413, "image_path": "images\\Camera_0\\frame_35910.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35940, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719414, "image_path": "images\\Camera_0\\frame_35940.jpg"}
# {"camera_id": "Camera_0", "frame_id": 35970, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719415, "image_path": "images\\Camera_0\\frame_35970.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36000, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719416, "image_path": "images\\Camera_0\\frame_36000.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36030, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719417, "image_path": "images\\Camera_0\\frame_36030.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36060, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719418, "image_path": "images\\Camera_0\\frame_36060.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36090, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719419, "image_path": "images\\Camera_0\\frame_36090.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36120, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695719420, "image_path": "images\\Camera_0\\frame_36120.jpg"}
# {"camera_id": "Camera_0", "frame_id": 36150, "geo_location": "(-63.084606, 153.385119)", "timestamp": 1695